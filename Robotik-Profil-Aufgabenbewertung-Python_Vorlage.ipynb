# %% [raw]
# # Python-Grundlagen: Aufgabenbewertung
#
# **Arbeitszeit:** ca. 2,5 Stunden
# **Zielgruppe:** Klasse 10
# **Thema:** Variablen, Zeichenketten, Zahlen, Gleitkommazahlen, Listen, Bedingungen, Schleifen und Funktionen
#
# ## Szenario
#
# In diesem Notebook bearbeitet ihr mehrere Aufgaben zu grundlegenden Python-Konzepten.
# Dabei geht es um Projektdaten, Listen, Berechnungen, Schleifen, Funktionen und am Ende um die Auswertung von Social-Media-Beiträgen.
#
# Dieses Notebook dient als **Bewertungsgrundlage**.
# Die Aufgaben können zu zweit oder einzeln bearbeitet werden. Einzelbearbeitungen erhalten einen Bonus von **20 %**.
#
# Achtet auf:
#
# - sinnvolle Variablennamen
# - korrekte Einrückung
# - verständliche Ausgaben
# - passende Nutzung von Funktionen
# - nachvollziehbare Berechnungen
# - saubere Programmstruktur

# %% [markdown]
# ## Hinweise zur Bearbeitung
#
# - Die Beispielausgaben dienen nur zur Orientierung und sollen **nicht einfach abgetippt** werden.
# - Führt die Code-Zellen nacheinander aus.
# - Verwendet sprechende Variablennamen.
# - Achtet besonders auf die Einrückung bei `if`, `for`, `while` und Funktionen.
# - Kommentare mit `#` sind erlaubt und erwünscht.
# - Achtet darauf, eingebaute Python-Funktionen wie `min`, `max`, `sum`, `list`, `str` oder `int` nicht als Variablennamen zu verwenden.

# %% [markdown]
# ## Bewertungsübersicht, 90 Punkte
#
# | Aufgabe | Inhalt | Punkte |
# |---:|---|---:|
# | 1 | Projektdaten mit Variablen speichern | 8 |
# | 2 | Gesamtkosten berechnen | 6 |
# | 3 | Listen verwenden | 6 |
# | 4 | Liste mit einer `for`-Schleife auswerten | 8 |
# | 5 | Bewertung mit `if`, `elif` und `else` | 4 |
# | 6 | Gruppeneinteilung mit `for`-Schleife und Modulo | 8 |
# | 7 | Punkteliste mit einer `while`-Schleife auffüllen | 6 |
# | 8 | Funktionen schreiben | 13 |
# | 9 | Abschlussaufgabe: Social-Media-Auswertung | 25 |
# | 10 | Reflexion | 6 |
#
# **Gesamt:** 90 Punkte

# %% [markdown]
# # Aufgabe 0: Namen!

# %% [markdown]
# # Aufgabe 1: Projektdaten mit Variablen speichern (8 Punkte)
#
# Lege Variablen für dein Klassenprojekt an. Hinweis zur Punktbewertung: Bezeichner 1 Punkt, Wert 1 Punkt
#
# Speichere mindestens:
#
# - den Namen des Projekts als Zeichenkette (`str`)
# - die Anzahl der Teilnehmenden als ganze Zahl (`int`, mind. 15)
# - die Kosten in Euro pro Person als Gleitkommazahl (`float`)
# - eine kurze Beschreibung als Zeichenkette (`str`)
#
# Gib anschließend einen kurzen Infotext mit `print()` aus, der alle gespeicherten Informationen enthält. Nutzt auch die {}-Variante zur Variablenausgabe.

# %%
# Aufgabe 1: Eigene Lösung

# %% [markdown]
# ## Beispielausgabe zu Aufgabe 1
#
# ```text
# Projekt: Workshop Robotik
# Beschreibung: Bau und Programmierung kleiner Roboter
# Teilnehmende: 24
# Kosten pro Person: 7.5 Euro
# ```

# %% [markdown]
# # Aufgabe 2: Gesamtkosten berechnen (6 Punkte)
#
# Berechne die Gesamtkosten des Projekts. Rundung auf zwei Stellen nach dem Komma.
#
# Zusatzregel:
#
# - Wenn mehr als 15 Personen teilnehmen, gibt es **10 % Rabatt** auf die Gesamtkosten.
# - Sonst wird der volle Preis berechnet.
#
# Gib aus:
#
# - Gesamtkosten ohne Rabatt
# - Rabattbetrag
# - Endpreis

# %%
# Aufgabe 2: Eigene Lösung

# %% [markdown]
# ## Beispielausgabe zu Aufgabe 2
#
# ```text
# Gesamtkosten ohne Rabatt: 180.0 Euro
# Rabatt: 18.0 Euro
# Endpreis: 162.0 Euro
# ```

# %% [markdown]
# # Aufgabe 3: Listen (6 Punkte)
#
# Für das Projekt müssen Namen hinterlegt und Punktzahlen vergeben werden.
# Vervollständige die Liste mit Namen und lege eine neue mit mindestens fünf Punktzahlen an.
#
# Bearbeite dann folgende Teilaufgaben:
#
# 1. Ergänze die Namensliste um so viele Namen, um die in Aufgabe 1 hinterlegte Gruppenstärke erreichen. Nutze `append()`.
# 2. Gib einmal die Namensliste aus.
# 3. Lege die Punktezahlenliste an (mind. 5).
# 4. Gib die Punkteliste aus.
# 5. Füge drei weitere Punktzahlen mit `append()` hinzu.
# 6. Gib die Anzahl der Einträge mit `len()` aus.
# 7. Gib die erste und die letzte Punktzahl der Liste aus.

# %%
# Aufgabe 3: eigene Lösung

# %% [markdown]
# ## Beispielausgabe zu Aufgabe 3
#
# ```text
# Namensliste Basis: ['Anna', 'Ben', 'Clara', 'David', 'Emma', 'Finn', 'Greta', 'Henry', 'Ida', 'Jonas', 'Klara', 'Leon']
# Namensliste erweitert: ['Anna', 'Ben', 'Clara', 'David', 'Emma', 'Finn', 'Greta', 'Henry', 'Ida', 'Jonas', 'Klara', 'Leon', 'Mia', 'Noah', 'Olivia', 'Paul', 'Quinn', 'Rosa']
#
# Punktzahlen: [12, 8, 15, 10, 14]
# Neue Punktzahlen: [12, 8, 15, 10, 14, 13, 4, 12, 10]
# Anzahl der Punktzahlen: 6
# Erste Punktzahl: 12
# Letzte Punktzahl: 13
# ```

# %% [markdown]
# # Aufgabe 4: Eine Liste mit einer `for`-Schleife auswerten (8 Punkte)
#
# Verwende eine `for`-Schleife, um alle Punktzahlen aus der Liste zu durchlaufen.
#
# Berechne:
#
# - die Summe aller Punkte
# - den Durchschnitt
# - die niedrigste Punktzahl
# - die höchste Punktzahl
#
# Es gibt passende Funktionen für die Extremwerte. Nutzt für einen Extremwert (Minimum/Maximum) eine solche Funktion und berechnet den anderen über die Schleife.

# %%
# Aufgabe 4: Eigene Lösung

# %% [markdown]
# ## Beispielausgabe zu Aufgabe 4
#
# ```text
# Punkte: [12, 8, 15, 10, 14, 13, 4, 12, 10]
# Summe: 98
# Durchschnitt: 10.89
# niedrigste Punktzahl: 4
# Höchste Punktzahl: 15
# ```

# %% [markdown]
# # Aufgabe 5: Eine Bewertung mit `if`, `elif` und `else` (4 Punkte)
#
# Bewerte den Durchschnitt der Punktzahlen.
#
# Regeln:
#
# - Durchschnitt unter 8: `Verbesserung nötig`
# - Durchschnitt ab 8 und unter 12: `solide Leistung`
# - Durchschnitt ab 12: `gute Leistung`
#
# Gib die passende Bewertung aus.

# %%
# Aufgabe 5: Eigene Lösung

# %% [markdown]
# ## Beispielausgabe zu Aufgabe 5
#
# ```text
# Durchschnitt: 10.89
# Bewertung: solide Leistung
#
# ```

# %% [markdown]
# # Aufgabe 6: Eine Gruppeneinteilung vornehmen (8 Punkte)
#
# Erstelle mit einer `for`-Schleife und dem Modulo-Operator eine nummerierte Ausgabe für die Projektgruppen. Pro Gruppe sollen 4 SchülerInnen zugeordnet werden. Die letzte Gruppe besteht aus 1-4 SchülerInnen. Zu Beginn soll ausgegeben werden, wieviele Gruppen benötigt werden.
#
# Vorgabe:
#
# ```python
# gruppengroesse = 4
# ```

# %%
# Aufgabe 6: Eigene Lösung

# %% [markdown]
# ## Beispielausgabe zu Aufgabe 6
#
# ```text
# Es werden 5 Gruppen benötigt
#
# Gruppe 1:
# Anna
# Ben
# Clara
# David
#
# Gruppe 2:
# Emma
# Finn
# Greta
#
# Gruppe 3:
# Henry
# Ida
# Jonas
# Klara
#
# Gruppe 4:
# Leon
# Mia
# Noah
# Olivia
#
# Gruppe 5:
# Paul
# Quinn
# Rosa
# ```

# %% [markdown]
# # Aufgabe 7: Punkteliste mit einer `while`-Schleife auffüllen (6 Punkte)
#
# Die Punkteliste enthält zunächst nur einige Werte.
# Ergänze mit einer `while`-Schleife automatisch weitere Punktzahlen, bis die Liste mindestens 8 Einträge enthält.
#
# Nutze dazu eine zweite Liste mit Ersatzwerten.
#
# Dein Programm soll:
#
# 1. prüfen, ob die Punkteliste weniger als 8 Einträge hat,
# 2. solange Werte ergänzen, bis 8 Einträge erreicht sind,
# 3. nach jeder Ergänzung die neue Liste ausgeben,
# 4. am Ende die fertige Punkteliste und ihre Länge ausgeben.

# %%
# Aufgabe 7: eigene Lösung

# %% [markdown]
# ## Beispielausgabe zu Aufgabe 7
#
# ```text
# Aktuelle Punktzahlen: [12, 9, 15, 11, 14, 10]
# Aktuelle Punktzahlen: [12, 9, 15, 11, 14, 10, 13]
# Aktuelle Punktzahlen: [12, 9, 15, 11, 14, 10, 13, 8]
# Fertige Punkteliste: [12, 9, 15, 11, 14, 10, 13, 8]
# Anzahl der Punktzahlen: 8
# ```

# %% [markdown]
# # Aufgabe 8: Funktionen schreiben (13 Punkte)
#
# Schreibe drei Funktionen. Nutze gern den bereits erstellen Code von früheren Aufgaben.
#
# ## Funktion 1
#
# ```python
# berechne_durchschnitt(liste)
# ```
#
# Die Funktion bekommt eine Liste mit Zahlen und gibt den Durchschnitt zurück.
#
# ## Funktion 2
#
# ```python
# bewerte_durchschnitt(wert)
# ```
#
# Die Funktion bekommt einen Durchschnittswert und gibt einen Bewertungstext zurück.
#
# Regeln:
#
# - unter 8: `Verbesserung nötig`
# - ab 8 und unter 12: `solide Leistung`
# - ab 12: `gute Leistung`
#
# ## Funktion 3
#
# ```python
# berechne_gesamtkosten(teilnehmer,kosten_pro_person,rabattgrenze,rabatt)
# ```
#
# Berechne die Gesamtkosten des Projekts. Sollte die Ausgabe auch in die Funktion integriert werden, wenn sie eigentlich nur berechnen soll? Finde eine Lösung, um doppelten Code zu vermeiden.
#
# Zusatzregel:
#
# - Wenn mehr als X Personen teilnehmen, gibt es **X % Rabatt** auf die Gesamtkosten.
# - Sonst wird der volle Preis berechnet.
# - folgende Werte sollen genutzt werden:
# - 1. TN=19, KpP=8,35 €, RG=12, R=15%
# - 2. TN=11, KpP=6,40 €, RG=15, R=40%
#
# Gib aus:
#
# - Teilnehmer, Kosten pro Person, Rabattgrenze, Rabatt
# - Gesamtkosten ohne Rabatt
# - Rabattbetrag
# - Endpreis

# %%
# Aufgabe 8: Eigene Lösung

# %% [markdown]
# ## Beispielausgabe zu Aufgabe 8
#
# ```text
# Punkteliste:  [12, 8, 15, 10, 14, 13, 4, 12, 10]
# Durchschnitt:  10.89
# Bewertung:  solide Leistung
#
# Teilnehmer: 19
# Kosten pro Person: 8.35 Euro
# Rabattgrenze: 12
# Rabatt: 15 %
# Gesamtkosten ohne Rabatt: 158.65 Euro
# Rabattbetrag: 23.8 Euro
# Endpreis: 134.85 Euro
#
# Teilnehmer: 11
# Kosten pro Person: 6.4 Euro
# Rabattgrenze: 15
# Rabatt: 40 %
# Gesamtkosten ohne Rabatt: 70.4 Euro
# Rabattbetrag: 0 Euro
# Endpreis: 70.4 Euro
#
#
# ```

# %% [markdown]
# # Aufgabe 9: Abschlussaufgabe - Auswertung Social Media (25 Punkte)
#
# Ein fiktiver Social-Media-Kanal hat mehrere Beiträge veröffentlicht. Die Liste mit den Beiträgen ist bereits vorgegeben.
#
# Jeder Beitrag besteht aus: AutorIn, Titel, Anzahl der Likes
#
# Für die Bewertung gilt:
#
# Für je 50 Likes gibt es einen Stern.
# Die Sterne werden als Gleitkommazahl berechnet.
# Beispiel:
# 50 Likes -> 1 Stern
# 125 Likes -> 2,5 Sterne
# 200 Likes -> 4 Sterne
# 220 Likes -> 4,2 Sterne
#
# Schreibe ein Python-Programm mit folgenden Funktionen:
#
# ## Funktion 1: Sterne berechnen
#
# `berechne_sterne(likes)`
#
# Die Funktion bekommt die Anzahl der Likes und gibt die Anzahl der Sterne zurück.
#
# ## Funktion 2: Sterne anzeigen
#
# `zeige_sterne(sterne)`
#
# Lass die Sterne anzeigen. Wie das optisch geht, findet ihr im Feld für eure Lösung.
#
# ## Funktion 3: Einen Beitrag ausgeben
#
# `gib_beitrag_aus(beitrag)`
#
# Die Funktion bekommt einen einzelnen Beitrag aus der Liste und gibt AutorIn, Titel, Likes und Sterne aus.
#
# Beispiel:
#
# ```text
# AutorIn: Anna
# Titel: Mein erster Beitrag
# Likes: 120
# Sterne: 2.4 ★★⯨
# ```
#
# ## Funktion 4: Ausgabe aller Beiträge inkl. Sterne
#
# `alle_beitraege()`
#
# Die Funktion soll alle Beiträge inkl. der berechneten und visuell dargestellten Beiträge aus. Nutze die Funktion der Beitragausgabe, aber passe diese Funktion (`gib_beitrag_aus(beitrag,"flach")` so an, dass eine flache Ausgabe erfolgt, also so:
# ```text
# Anna: "Mein erster Beitrag", 120 Likes, 2.4 ★★⯨
# ```
#
# ## Funktion 5: Ausgabe aller Beiträge eines/r AutorIn
#
# `gib_beitraege_von_autor_aus(beitraege, autor_name)`
#
# Die Funktion soll alle Beiträge einer bestimmten AutorIn ausgeben.
#
# Wichtiger Hinweis:
# Diese Funktion soll die Funktion `gib_beitrag_aus(beitrag)` benutzen.
# Das bedeutet: Die AutorInnen-Funktion sucht nur die passenden Beiträge. Die Ausgabe eines einzelnen Beitrags übernimmt die Beitragsfunktion.

# %%
 # Aufgabe 9: eigene Lösung

beitraege = [
    ["Anna", "Mein erster Beitrag", 120],
    ["Ben", "Python-Tipps", 85],
    ["Clara", "Schulprojekt gestartet", 230],
    ["David", "Hinter den Kulissen", 45],
    ["Emma", "Unsere Gruppenarbeit", 160],
    ["Finn", "Kurzer Lernhack", 75],
    ["Greta", "Umfrage der Woche", 310],
    ["Henry", "Coding macht Spaß", 95],
    ["Anna", "Neue Ideen", 180],
    ["Ben", "Fehler finden", 55],
    ["Clara", "Projektupdate", 270],
    ["David", "Wochenrückblick", 130],
    ["Emma", "Teamarbeit", 90],
    ["Finn", "Mini-Tutorial", 205],
    ["Greta", "Quizfrage", 40],
    ["Henry", "Programmier-Challenge", 150],
    ["Anna", "Abschlussbericht", 260],
    ["Ben", "Debugging-Tipps", 115],
    ["Clara", "Unser Ergebnis", 340],
    ["David", "Danke fürs Mitmachen", 70]
]


def zeige_sterne(sterne):
    voller_stern = "\u2605"       # ★
    leerer_stern = "\u2606"       # ☆
    halber_stern = "\u2BE8"       # ⯨

 
# Aufruf der Funktionen
gib_beitrag_aus(beitraege[0])

alle_beitraege()

gib_beitraege_von_autor_aus(beitraege, "Anna")
gib_beitraege_von_autor_aus(beitraege, "Finn")

# %% [markdown]
# ```text
# AutorIn: Anna
# Titel: Mein erster Beitrag
# Likes: 120
# Sterne: 2.4 ★★⯨
#
# Anna: "Mein erster Beitrag", 120 Likes, 2.4 ★★⯨
# Ben: "Python-Tipps", 85 Likes, 1.7 ★⯨
# Clara: "Schulprojekt gestartet", 230 Likes, 4.6 ★★★★⯨
# David: "Hinter den Kulissen", 45 Likes, 0.9 ★
# Emma: "Unsere Gruppenarbeit", 160 Likes, 3.2 ★★★☆
# Finn: "Kurzer Lernhack", 75 Likes, 1.5 ★⯨
# Greta: "Umfrage der Woche", 310 Likes, 6.2 ★★★★★★☆
# Henry: "Coding macht Spaß", 95 Likes, 1.9 ★★
# Anna: "Neue Ideen", 180 Likes, 3.6 ★★★⯨
# Ben: "Fehler finden", 55 Likes, 1.1 ★☆
# Clara: "Projektupdate", 270 Likes, 5.4 ★★★★★⯨
# David: "Wochenrückblick", 130 Likes, 2.6 ★★⯨
# Emma: "Teamarbeit", 90 Likes, 1.8 ★★
# Finn: "Mini-Tutorial", 205 Likes, 4.1 ★★★★☆
# Greta: "Quizfrage", 40 Likes, 0.8 ★
# Henry: "Programmier-Challenge", 150 Likes, 3.0 ★★★
# Anna: "Abschlussbericht", 260 Likes, 5.2 ★★★★★☆
# Ben: "Debugging-Tipps", 115 Likes, 2.3 ★★⯨
# Clara: "Unser Ergebnis", 340 Likes, 6.8 ★★★★★★★
# David: "Danke fürs Mitmachen", 70 Likes, 1.4 ★⯨
#
# === Beiträge von Anna ===
# AutorIn: Anna
# Titel: Mein erster Beitrag
# Likes: 120
# Sterne: 2.4 ★★⯨
#
# AutorIn: Anna
# Titel: Neue Ideen
# Likes: 180
# Sterne: 3.6 ★★★⯨
#
# AutorIn: Anna
# Titel: Abschlussbericht
# Likes: 260
# Sterne: 5.2 ★★★★★☆
#
# === Beiträge von Finn ===
# AutorIn: Finn
# Titel: Kurzer Lernhack
# Likes: 75
# Sterne: 1.5 ★⯨
#
# AutorIn: Finn
# Titel: Mini-Tutorial
# Likes: 205
# Sterne: 4.1 ★★★★☆
# ```

# %% [markdown]
# # Reflexion (6 Punkte)
#
# Beantworte kurz in eigenen Worten:
#
# 1. Wofür wurden in deinem Programm Variablen verwendet? (2 Punkte)
# 2. Warum ist eine Liste für mehrere Punktzahlen sinnvoll? (1 Punkt)
# 3. Was passiert, wenn bei einer Schleife die Zählvariable nicht verändert wird? (1 Punkte)
# 4. Warum sind Funktionen nützlich?  (2 Punkte)
#
# Schreibe deine Antworten in die nächste Zelle.

# %% [markdown]
# ## Antworten
#
# 1.
# 2.
# 3.
# 4.
