# %% [markdown]
# # Was ist ein Jupyter Notebook?
#
# Hier gibt es eine minimale Einleitung zum Umgang mit den Jupyter-Notebooks.

# %% [markdown]
# ## Quellen
#
# [Variablen](https://user.phil.hhu.de/~seyffarth/classes/python2020/02-01%20Variablen.pdf)
#
# [Schleifen](https://www.python-kurs.eu/schleifen.php)
#
# [Schleifen 2](https://firedynamics.github.io/LectureComputerScience/content/Script/02_python/0231_schleifen.html)
#
# [Python Dictionaries](https://www.w3schools.com/python/python_dictionaries.asp)
#
# [Datentypen und Variablen](https://www.python-kurs.eu/python3_variablen.php)

# %% [markdown]
# ## Zweck
# Das Jupyter Notebook besteht aus Zellen, diese können ausgeführt werden. Es gibt Text-Zellen (Markdown) oder Code-Zellen.

# %% [markdown]
# ## Ausführung der Zellen
# An der Seite einer aktiven Zelle ist eine Markierung, durch drücken der Tasten Shift und Enter wird eine Zelle ausgeführt.

# %% [markdown]
# ### Ausführen von Text-Zellen
# Beim ausführen von Text-Zellen passiert nicht so viel, die Markierung am linken Rand springt nur zur nächsaten aktiven Zelle.
#
# Durch Doppel-Klicken einer Text-Zelle gelangst du in den Editier-Modus und kannst die Zelle bzw. deren Text verändern.

# %% [markdown]
# ### Ausführen von Code-Zellen
#
# Bei der Ausführung von Code-Zellen wird der Code des geschriebenen Programms ausgeführt.

# %% [markdown]
# ## Unterschied Markdown-Zelle
# In diesen Zellen ist vorrangig Text, wie Aufgabenstellungen Fragen und Ähnliches. Den Text kann man mit HTML-Tags oder Latex bzw. Markdown gestalten.
#
# **Aufgabe 1:** 23 * 12 = 276
#
# **Aufgabe 2:** Was ist die größe einstellige Primzahl: 7
#
# **Aufgabe 3:** Berechne die Aufgabe oben mit Hilfe der "russischen Bauernmultiplikation"!
#
# 23 | 12  |  ungerade
#
# 11 | 24  |  ungerade
#
#  5 | 48  |  ungerade
#
#  2 | 96  |  gerade
#
#  1 | 192 |  ungerade
#
#
# 12 + 24 + 48 + 192 = 276
#
# 23 * 12 = 276

# %% [markdown]
# ## Unterschied Code-Zelle
#
# **Aufgabe 4:** Führe die untenstehenden Code einmal aus!
#
# **Aufgabe 5:** Wandele den Code ab, sodass dass Programm: "Hallo Tom" ausgibt, wobei du deinen Vornamen nutzt anstelle von Tom!

# %%
# In diesen Zellen kann man Programm-Code definieren
print("Hallo Tom") # sollte hier nicht Luzi stehen
# Out:
# Hallo Tom

# %% [markdown]
# # Einleitung Programmierung
#
# Hallo liebe Schülerinnen und Schüler des Curie Gymnasiums, hier beginnt unsere Reise in die Welt der Informatik. Und wir beginnen mit Variablen, deren Datentypen und dem Anzeigen von Variablen.

# %%
print("Hallo hier beginnt die Reise.")
# Out:
# Hallo hier beginnt die Reise.

# %% [markdown]
# # Variablen aus der Mathematik
#
# Gegeben ist das folgende Beispiel aus der Geometrie
#
# ![alt text](../shared/img_curie_course/curie_robo_kurs_var_example.png "Title")
#
# Abb. 1: ein Rechteck

# %% [markdown]
# **Aufgabe 6:** Bitte füge alle Seitenbezeichnungen und Längen ein nutze dabei folgende Form, siehe unten.
#
# Die Länge der Seite b ist halb so lang wie Seite a.

# %% [markdown]
# Bitte vervollständige die Seiten des Rechtecks.
#
# Seiten und Längen:
# - a = $\overline{AB}$ = 39 cm
# - b = $\overline{CB}$ = 19,5 cm
# - c = $\overline{DC}$ = 39 cm
# - d = $\overline{DA}$ = 19,5 cm

# %% [markdown]
# Die Buchstaben a bis d sind in der Mathematik Variablen, welche in dem Beispiel von Abbildung 1 sehr konkrete Werte besitzen.
#
# **Aufgabe 7:** Gib die Seiten und deren Längen von einem weiteren selbstgewählten Rechteck als Beispiel an.

# %% [markdown]
# Mein Beispiel:
# - a:  46 cm
# - b:  23 cm
# - c:  46 cm
# - d:  23 cm

# %% [markdown]
# **Merke**
#
# Eine Variable ist in der Mathematik ein Bezeichner, wie der kleine Buchstabe "b" und dieser kann für einen belibigen Wert einer Seitenlänge stehen. Das heißt "b" kann jeden beliebigen gültigen Wert annehmen.

# %% [markdown]
# # Variablen in der Informatik
#
# Eine Variable in der Informatik ist eine Aufbewahrungskonstrukt für Werte.
#
# Diese Variablen haben einen Bezeichner und mit Hilfe von diesem Bezeichner kann man ihr einen Wert zu weisen.

# %%
# a: ist der Bezeichner d.h. der Name der Variable
# 19.5: ist der Wert der, der Variable zugewiesen wird
# = ist der Zuweisungsoperator in Python
a = 19.5 

print("(Option a) Wert der Variablen a: \n", a)

print("(Option b)")
a # einfach die Variable in die letzte Zeile schreiben
# Out:
# (Option a) Wert der Variablen a:
#  19.5
# (Option b)
# 19.5

# %% [markdown]
# **Aufgabe 8:**
#
# Lass dir in einer Zelle den Wert deiner Variable ausgeben!
#
# Gibt es hierfür noch weitere Möglichkeiten?
#
# Wie sollte man Variablen in Python bezeichnen oder generell in der Programmierung? Gib ein Beispiel an!

# %% [markdown]
# Antwort: In Jupyter Notebook muss man variablen nicht mit print ausgeben, es reicht, sie einfach hinzuschreiben.

# %%
##
# Lösung Aufgabe 8
##

number_of_elements = 20

print(number_of_elements)
# Out:
# 20

# %% [markdown]
# ## Typen von Variablen
#
# In Python gibt es neben ganzzahligen Zahlen (**Integers**) wie 1, 2, 3, 4, usw.
# noch Gleitkommazahlen (**float**) wie 1,1; 1,2; 1,3; 1,4; usw.

# %% [markdown]
# Allerdings benutzt man zum Schreiben der **Gleittkommazahlen die englische Schreibweise** also mit Punkt: 1.2

# %% [markdown]
# Neben Zahlen kann man Variablen Noch **Zeichen oder Zeichenketten** zuweisen, wie "Hallo" oder "Test 1234"

# %% [markdown]
# Derüber hinaus kann man Variablen auch Datenstrukturen zuweisen, wie Listen [1,2,1,3,4,3,4] (etwa eine Liste von Schulnoten)

# %% [markdown]
# **Aufgabe 9:** Bitte weise jedem Bezeichner einen selbstgewählten Wert zu und lass dir diesen Wert ausgeben!

# %%
##
# Zuweisung der Werte
##

ganze_zahl = 8
komma_Zahl = 12.4
zeichen_kette = "Hallo"
var_liste = [3, 4, 6, 5, 1, 2]

# %%
##
# Ausgabe der Werte
##

print(ganze_zahl)
print(komma_Zahl)
print(zeichen_kette)
print(var_liste)
# Out:
# 8
# 12.4
# Hallo
# [3, 4, 6, 5, 1, 2]

# %% [markdown]
# Nehmen wir nun nochmal das Beispiel des Rechtecks von oben.
#
# Es wurde nun um die Koordinaten der Punkte A bis C erweitert.
#
# **Aufgabe 10:** Weise die Koordinaten den Variablen zu.
#
# ![alt text](../shared/img_curie_course/curie_robo_kurs_var_example_2.png "Title")
#
# Abb. 2: ein Rechteck, samt Koordinaten im kartesischen Koordinaten-System

# %% [markdown]
# Fragen:
# - Wie soll das gehen?
#
# **Tipp:**
# - Denke an die Zuweisung der Datenstrukturen.
# - Eine Koordinate ist eine zwei-wertige Liste.

# %%
##
# Zuweisung der Werte
##

A=[-8,0]
B=[39,0]
C=[39,19.5]
D=[0,19.5]

# %% [markdown]
# ## Operatoren von Zahlen in Python
#
# Die Grundlegenden mathematische Operatoren sind:
#
# - Addition
# - Subtraktion
# - Multiplikation
# - Division

# %%
# Beispiel für die Addition
result = 123 + 915

# 2 weitere Beispiele für die Addition:

result = 67 + 754

result = 890 + 36

# %%
# Beispiel für die Subtraktion
result = 123 - 8657

# 2 weitere Beispiel für die Subtraktion:

result = 101 - 24

result = 799 - 234

# %%
# Beispiel für die Multiplikation
result = 1234 * 567

# 2 weitere Beispiel für die Multiplikation:

result = 635 * 89

result = 702 * 344

# %%
# Beispiel Division
result = 125 / 25

# 2 weitere Beispiel für die Division:

result = 566 / 34

result = 171 / 19

# %% [markdown]
# **Aufgabe 11:** Welchen Wert hat die Variable "result" ?
#
# Die Variable "result" hat den Wert 5.0.

# %% [markdown]
# **Aufgabe 12:** Gib für jede Rechenoperation, zwei weitere Beispiele an.

# %% [markdown]
# ## Zugriff auf Listen-Strukturen
#
# Auf eine Liste kann man über ihre jeweiligen Indizes auf die einzelnen Elemente zugreifen.

# %%
einkausliste = ["Brot", "Butter", "Käse"]

# %% [markdown]
# Welche Ausgabe erzeugt der folgende Zugriff?
#
# Vermutung: Brot

# %%
einkausliste[0]
# Out:
# 'Brot'

# %% [markdown]
# Welche Ausgabe erzeugt der folgende Zugriff?
#
# Vermutung: Eine Fehlermeldung, es gibt keinen Wert an der vierten Stelle in der Liste.

# %%
einkausliste[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-02d66de973ad> in <module>
# ----> 1 einkausliste[4]
#
# IndexError: list index out of range

# %% [markdown]
# ## Rechnen mit Listenelementen
#
# **Aufgabe 13:** Greife auf den y-Wert des Punktes A zu!

# %%
##
# schreibe deinen Zugriff hier hinein
##

print("y-Wert von Punkt A: ", A[1])
# Out:
# y-Wert von Punkt A:  0

# %% [markdown]
# **Aufgabe 14:** Greife lesend auf den x-Wert des Punktes A zu.

# %%
##
# schreibe deinen Zugriff hier hinein
##

print("x-Wert von Punkt A: ", A[0])
# Out:
# x-Wert von Punkt A:  -8

# %% [markdown]
# **Aufgabe 15:** Berechne den Mittelpunkt der Seite "a"!

# %%
##
# schreibe deine Berechnung hier hinein
##

mittelpunkt_a = (B[0] + abs(A[0])) / 2 # Wieso der Betrag?
                                       # Wie sieht die Aufgabe ohne Verwendung des Betrags aus? 

print(mittelpunkt_a)
# Out:
# 23.5

# %% [markdown]
# **Aufgabe 16:** Berechne mit Hilfe der Koordinaten der Punkte B und C, den Flächeninhalt des Rechtecks aus Abbildung 2 von oben.
#
# Bitte ohne Funktion.

# %%
##
# schreibe deine Berechnung hier hinein
##

flaecheninhalt = B[0] * C[1] # Bezeichner koennen auch englisch sein
print("Ergebnis des Flächeninhalts: ", flaecheninhalt)
# Out:
# Ergebnis des Flächeninhalts:  760.5

# %% [markdown]
# ## Die Verwendung von Schleifen bei sich wiederholenden Aufgaben
#
# Die Grundlegenden Schleifenarten in Python sind:
#
# - for-Schleifen
# - while-Schleifen

# %% [markdown]
# ### For-Schleifen
#
# Die For-Schleife verwendet man, wenn man über eine genau definierte Anzahl von Elementen gehen möchte, bzw. man genau weiß wie oft etwas passieren soll.

# %%
noten = [
    1, 2, 3, 1, 4, 5, 6, 2, 3, 4, 2, 1
]

# %% [markdown]
# **Aufgabe 17:** Ein Kollege hat bereits die Berechnungsfunktion implementiert. Aber sie muss noch getestet werden. Bitte prüfe die Summe der Noten händisch nach und finde den Fehler.
#
# Tipp: Benutze das gute alte printf-Debugging

# %%
summe = 0

for element in noten:
    summe += element
    
summe
# Out:
# 34

# %% [markdown]
# **Aufgabe 17b:** Beschreibe den Fehler im Detail:
#
# Der Fehler entsteht, weil in der Schleife element fälschlich als Index verwendet wird. Da element aber schon die Werte aus der Liste enthält, muss man stattdessen summe += element schreiben.

# %% [markdown]
# **Aufgabe 18:** Berechne die Summe aller Noten, mit der Nutzung der range Funktion und der len Funktion.
#
# Nutze die **for** Schleife, nutze die Funktionen **in** und **range** für den Schleifendurchlauf.

# %%
summe_2 = 0


for index in range(len(noten)):
    summe_2 += noten[index]
   
    
summe_2
# Out:
# 34
