# %% [markdown]
# # Abgabe
#
# Hallo hier in dieses separate Notebook, soll deine erstellte Tabelle eingefügt werden.
#
# Bitte ändere den Namen dieses Bewertungsnotebooks wie folgt ab: Vorlage_Bewertung_01_vorname_nachname.ipynb [1] und sende das Notebook an:
#
# - falko.gawantka@hszg.de
# - oliver.nitschke@hszg.de
#
# [1]: Wenn dein Name Jane Doe ist heißt, das Notebook dann: Vorlage_Bewertung_01_jane_doe.ipynb.

# %% [markdown]
# ## Hier bitte Tabelle einfügen
#
# (Hier rein dein Tabelle kopieren)
#
# (Der Editier-Modus wird durch Doppelklicken geöffnet.)
