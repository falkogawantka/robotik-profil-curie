# %% [markdown]
# # Abgabe
#
# Hallo,
#
# in dieses separate Notebook sollst du deine programmierte **Funktion der zweiten Bewertungsaufgabe** einfügen.
#
# Bitte benenne dieses Bewertungsnotebook wie folgt um:
# `Vorlage_Bewertung_02_vorname_nachname.ipynb` [1]
# und sende das Notebook anschließend an:
#
# - falko.gawantka@hszg.de
# - oliver.nitschke@hszg.de
#
# [1]: Beispiel: Wenn dein Name *Jane Doe* ist, heißt das Notebook
# `Vorlage_Bewertung_02_jane_doe.ipynb`.

# %% [markdown]
# ## Hier unter diese Überschrift bitte den Code deiner Funktion einfügen

# %%
##
#
# Bitte kopiere deine Funktion hier hinein.
#
##

def calc_length_to_waypoint(length_a: float, length_b: float):
    return -1
