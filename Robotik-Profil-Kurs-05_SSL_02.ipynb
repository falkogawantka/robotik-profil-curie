# %% [markdown]
# # Robotik-Profil Curie Teil 5

# %% [markdown]
# ## Übung zum selbstständigen Lernen - 2
#
# Der zweite Block zum selbstständigen Üben soll Funktionen und deren Umsetzung wiederholen.
#
# Wir hatten bisher eine Funktion als kleinere Folge von Arbeitsschritten innerhalb eines übergeordneten Ziels kennengelernt.
#
# Die Analogie war, das wenn man einen Kuchen backt (der aus mehreren Schritten besteht) eine sich wiederkehrende Folge wie das Abmessen einzelner Zutaten als einen kleinen Hilfsprozess betrachtet (d. h. Funktion).

# %% [markdown]
# ## Quellen
#
# - [Funktionen in Python - Web](https://www.python-lernen.de/funktionen-in-python.htm)
# - [Einführen ins Programmieren mit Python - Buch Web](https://pythonbuch.com/funktion.html)
# - [Funktionen in Python - Web](https://www.datacamp.com/de/tutorial/functions-python-tutorial)

# %% [markdown]
# # Wiederholung
#
# Vom letzten Mal sollten folgende Begriffe bekannt sein:
#
# - **Funktionen**
# - **Rückgabe von Werten**

# %% [markdown]
# **Aufgabe 1**:
#
# Im Folgenden ist eine Funktionen gegeben, die einen Nutzer grüßt

# %% [markdown]
# ## A) Funktion

# %%
##
# Code Aufgabe
##

def greet(name_):
    print("Hello", name_)
    
greet("John")

# %% [markdown]
# **Frage**:
#
# Gibt diese Fuktion im Sinne der Programmierung etwas zurück?
#
# <details>
#  <summary> Lösung </summary>
#
#  <p>
#  Nein. Es wird nur trotzdem etwas angezeigt, weil die Variablen oder Ausgabe die als letztes in einer Zelle steht, wird in einem Jupyter-Notebook angezeigt. (Das ist nur hier so.)
#  </p>
# </details>

# %% [markdown]
# ## Begründung
#
# Damit eine Funktion einen Wert zurück gibt, musst du das Schlüsselwort **return** benutzen und einen Wert oder eine Variable zurückgeben.

# %% [markdown]
# ## B) Beispiel einer Funktion mit return-Anweisung

# %%
##
# Code Aufgabe
##

def greet(name_):
    return "Hello ", name_

# %% [markdown]
# **Frage:**
#
# Warum gibt dies Funktion nichts zurück?

# %% [markdown]
# <details>
#  <summary> <b>Lösung</b> </summary>
#  <p>
#  Die Funktion gibt etwas zurück aber es verpufft, weil du es nicht entgegen nimmst.
#  </p>
# </details>

# %% [markdown]
# ## C) Beispiel einer Funktion mit return-Anweisung und Weiterverarbeitung

# %%
##
# Code Aufgabe
##

def greet(name_):
    return "Hello " + str(name_)

print(greet("Daphne"))

# %% [markdown]
# <details>
#  <summary> <b>Lösung</b> </summary>
#  <p>
#  Die Funktion gibt eine Begrüßung des Nutzers Daphne zurück, die Funktion print() nimmt die Zeichenkette und zeigt diese an.
#  </p>
# </details>

# %% [markdown]
# ## Funktionen können Dinge berechnen
#
# In der Programmierung werden Funktionen sehr oft eingesetzt, um wiederkehrende Aufgaben zu erledigen.
#
# Hierzu vergibt einen Namen für die Funktion **addiere_zwei_zahlen**.
#
# Als Nächstes muss man der Funktion Platzhalter für ihre zu addierenden Zahlen geben (**a**, **b**).
#
# Um das Ergebnis zurückzubekommen, muss man das Schlüssel Wort **return** benutzen.

# %% [markdown]
# ## D) Beispiel einer Additionsfunktion

# %%
def addiere_zwei_zahlen(a, b):
    return a + b

# %% [markdown]
# # Neuer Aufgabenteil

# %% [markdown]
# **Aufgabe 2:**
#
# Schreibe drei Beispielaufrufe der Funktion **addiere_zwei_zahlen()** und gib dieser je zwei Zahlen mit.
#
# Schreibe je einen Aufruf in eine **print()**-Funktion.

# %%
##
# Code
##

print()
print()
print()

# %% [markdown]
# **Aufgabe 3:**
#
# Schreibe eine Funktion **addiere_zahlen** diese soll eine Liste von Zahlen entgegennehmen und das Ergebnis zurückgebeben.

# %%
liste_ = [128, 597, 1012, 12, -12, 87, 1014]

# %%
##
# Code
##

def addiere_zahlen(zahlen):
    
    return 0

# %% [markdown]
# <details>
#  <summary> <b>Hilfe 1</b> </summary>
#  <p>
#  Du musst durch das Array gehen. (Tipp: Nutze eine Schleife.)
#  </p>
# </details>

# %% [markdown]
# <details>
#  <summary> <b>Hilfe 2</b> </summary>
#  <p>
#  Du musst die Zahlen alle aufaddieren, am besten in einer Variable (z. B. ergebnis ... besser englisch: result).
#  </p>
# </details>

# %% [markdown]
# <details>
#  <summary> <b>Hilfe 3</b> </summary>
#  <p>
#  Du musst diese Variable zurückgeben.
#
#  Also ersezte die 0, durch deine Variable in der die Summe steht.
#  </p>
# </details>

# %% [markdown]
# **Aufgabe 4**:
#
# Schreibe eine Funktion, die eine Liste von Zahlen Multipliziert.

# %%
liste_2_ = [1, 2, 3, 4, 5, 6, 7]
liste_3_ = [123, 67, 256, 91]

# %%
##
# Code
##

def multipliziere_zahlen(zahlen):
    pass

# %% [markdown]
# ## Berechnung von geometrischen Figuren
#
# ### Ein einfaches Beispiel
#
# <img src="../shared/img_curie_course/Rectangle.svg" alt="Bob the Robot" style="width: 500px;"/>
#
# Abb. 1: [Wikipedia Link](https://de.wikipedia.org/wiki/Rechteck#/media/Datei:Rectangle.svg)

# %% [markdown]
# **Aufgabe 5**:
#
# Berechne den Flächeninhalt eines Rechteckes,
#
# mit Hilfe der Funktion **calc_rectangle_area()**,
#
# welcher du die Längen der Seiten mitgibst.
#
# Dazu musst du nur das Produkt aus **a** und **b** bilden.
#
# Unten ist die Schablone dieser Funktion gegeben.

# %%
##
# Code
##

def calc_rectangle_area():
    pass

# %% [markdown]
# **Aufgabe 6**:
#
# Schreibe einen Test für dein Programm mit folgenden Parametern.
#
# Die Länge der **Seite a** soll **81 cm** betragen und **Seite b 45 cm**.

# %%
##
# Code
##

print(calc_rectangle_area())

# %% [markdown]
# ### Ein etwas komplexeres Beispiel

# %% [markdown]
# <img src="../shared/img_curie_course/cube.svg" alt="Cube" style="width: 400px;"/>
#
# Abb. 2: [Link zum Bild](https://svgsilh.com/de/image/296808.html)

# %% [markdown]
# Oben auf dem Bild siehst du einen Würfel. Das besondere an einem Würfel ist das alle Kanten gleich lang sind und er aus sechs gleich großen Flächen besteht.

# %% [markdown]
# **Formel zur Berechnung des Oberflächeninhalt eines Würfels**:
#
# $$A = 6 \cdot a^2$$

# %%
##
# Python Tipp
# zur Berechnung von Potenzen
##

ergebnis1 = 6 * 6 # normal wie aus der Mathematik
ergebnis2 = 5**2 # Python Schreibweise

print(ergebnis1)
print(ergebnis2)

# %% [markdown]
# **Aufgabe 7**:
#
# Schreibe eine Funktion, welche den **Flächeninhalt** eines beliebigen **Würfels berechnet** und diesen Wert **zurückliefert**.

# %%
##
# Code
##

def calc_surface_cube(length_of_a: float):
    return -1

# %% [markdown]
# **Aufgabe 8**:
#
# Führe die untenstehenden Testfälle aus und vergleiche die Ergebnisse deiner implementierten Funktion mit den Sollwerten.
#
# Diese Werte sollten übereinstimmen.

# %%
##
#
# Tests
#
##

print("Soll: 216 - Ist: " , calc_surface_cube(6.0))
print("Soll: 937.5 - Ist: " , calc_surface_cube(12.5))
print("Soll: 86.64 - Ist: " , calc_surface_cube(3.8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-257f83fc9bcd> in <module>
#       5 ##
#       6
# ----> 7 print("Soll: 216 - Ist: " , calc_surface_cube(6.0))
#       8 print("Soll: 937.5 - Ist: " , calc_surface_cube(12.5))
#       9 print("Soll: 86.64 - Ist: " , calc_surface_cube(3.8))
#
# NameError: name 'calc_surface_cube' is not defined

# %% [markdown]
# # Zweite Bewertungsaufgabe
#
# Der Roboter Bob soll genutzt werden, um unwegsames Terrain zu erkunden.
#
# Die Arbeitsweise soll hierbei wie folgt sein (er arbeitet sich iterativ vorwärts):
#
# 1. d. h. er **nimmt** seine **Umgebung wahr** (durch Sensoren)
# 2. er **verarbeitet** diese **Sensorwerte** und legt ein neues Ziel fest (Position)
# 2. er fährt zu dieser Position und staret wieder bei **Schritt 1**
#
# <img src="../shared/img_curie_course/Robo_Bob.png" alt="Bob the Robot" style="width: 450px;"/>
#
# Abb. 3: Bob der sich autonom bewegen kann.

# %% [markdown]
# # Problemstellung
#
# Bob startet vom Ausgangspunkt **A**.
#
# Nachdem Bob die Umgebung gescannt, hat findet eine **Künstliche Intelligenz** eine mögliche **neue Position** (d. h. Lücke), falls es eine gibt.
#
# Bobs Künstliche Intelligenz bezeichnet diese Lücke als **B** und gibt die **Koordinaten** dieses neuen Punkts zurück.
#
# Es gibt ein Problem im Team, welches die Steuerung von Bob Programmiert. Jemand ist krank und du musst aushelfen.
#
# Es muss noch berechnet werden, **wie weit die Entfernung zum neuen Punkt B ist**, die Richtung kann schon berechnet werden.

# %% [markdown]
# # Modellierung des Problems
#
# Ein netter Kollege (Marcel) hat das Problem grafisch dargestellt.
#
# Da Bob **schrittweise** ein Gebiet **erkundet**,
#
# fängt er immer bei den Koordinaten **A (0, 0)** an (von jedem Schritt aufs neue).
#
# Seine KI gibt ihm den **neuen Zielpunkt**, in dem Fall **B (-24, 45)** an, diese Koordinaten können in jedem Schritt anders sein.
#
# Der **Punkt C** **ergibt sich** aus den Koordinaten A und B.
#
# Es handelt sich um ein **rechwinkeliges Dreieck** bei dem die Länge der **längsten Seite ermittelt werden muss**.
#
# Die **Strecke AC** kann auch als **a** angesehen werden,
#
# die **Strecke BC** kann auch als **b** angesehen werden.

# %% [markdown]
# # Grafische Darstellung
#
# <img src="../shared/img_curie_course/Problem_Bob.svg" alt="The Robots Problem" style="width: 450px;"/>
#
# Abb. 4: Der Ausgangspunkt A und der neue Zielpunkt B sowie der Hilfspunkt C.

# %% [markdown]
# **Aufgabe zur Bewertung**:
#
# Schreibe eine Funktion, die die Pfadlänge zu dem neuen Punkt berechnet.
#
# Bedingung 1: Es muss möglich sein, mit Kommazahlen zu rechnen.
#
# Bedingung 2: Das Ergebnis soll von der Funktion zurückgegeben werden.

# %%
##
# Code der zweiten Bewertungsaufgabe
# diesen Abschnitt bitte vollständig kopieren in die Datei Vorlage_Bewertung_02.ipynb
##

def calc_length_to_waypoint(length_a: float, length_b: float):
    return -1

# %%
##
#
# Test zur Überprüfung deiner Funktion
#
##

print("Soll: 6.4 - Ist: ", calc_length_to_waypoint(4, 5)) 
print("Soll: 13.28 - Ist: ", calc_length_to_waypoint(12.5, 4.5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0ab1d37c8ad9> in <module>
#       5 ##
#       6
# ----> 7 print("Soll: 6.4 - Ist: ", calc_length_to_waypoint(4, 5))
#       8 print("Soll: 13.28 - Ist: ", calc_length_to_waypoint(12.5, 4.5))
#
# NameError: name 'calc_length_to_waypoint' is not defined
