# %% [markdown]
# # Robotik-Profil Curie Teil 6

# %% [markdown]
# ## Übung zum selbstständigen Lernen - 2
#
# Im vierten Block des Robotik Profils sollen Funktionen und deren Umsetzung wiederholt werden vor dem HIntergrund der Nutzung auf dem Calliope.
#
# Wir hatten bisher eine Funktion als kleinere Folge von Arbeitsschritten innerhalb eines übergeordneten Ziels kennengelernt.
#
# Die Analogie war, das wenn man einen Kuchen backt (der aus mehreren Schritten besteht) eine sich wiederkehrende Folge wie das abmessen einzelner Zutaten als einen kleinen Hilfsprozess betrachtet (d.h. Funktion).

# %% [markdown]
# ## Der Calliope - Kurzvorstellung
#
# Der Calliope ist ein System on Chip (Soc).
#
# Das heißt er hat alle Bestandteile eines Computer auf einem Chip
#
# und zusätzlich sind auf seiner Platine einige Buttons und weitere Anzeigeelemente.

# %% [markdown]
# ## Bob der Roboter
#
# Bob kennt ihr sicherlich noch er soll auf bestimmten unbemannten Missionen eingesetzt werden.
#
# Um seine aufgaben zu erledigen besitzt er einen speziellen Computer bzw. Chip.

# %% [markdown]
# <img src="images/Robo_Bob.png" alt="Bob the Robot" style="width: 450px;"/>

# %% [markdown]
# ## Das ist der Calliope
#
# Er ist der SoC von Bob.

# %% [markdown]
# <img src="images/Calliope_v3.jpg" alt="Bob the Robot" style="width: 450px;"/>

# %% [markdown]
# Der Calliope ist ein ein Platinen COmputer mit Buttons, Touch Pins und Aktoren wie etwa einer LED Matrix.

# %% [markdown]
# ## Der Wechsel von der Desktop Programmierung zur Programmierung von eingebetteten Systemen

# %% [markdown]
# Der Calliope kann über eine Entwicklungsumgebung in einer Website programmiert werden.
#
# Der Name der Website ist [makecode.calliope.cc](https://makecode.calliope.cc/).
#
# Auf dieser Website kann man neue Projekte anlegen, anschließend muss man einen Namen für das Projekt eingeben und bestätigen.

# %% [markdown]
# ## Schwierigkeit
#
# Bei der Website werden bestimmte Sprachelemente von Python genutzt die etwas modifiziert sind.
#
# Hier soll es darum gehen diese Sprachelemente zu verstehen, um den Wechsel zur Plattform gut zu bewältigen

# %% [markdown]
# ### Erste Besonderheit

# %% [markdown]
# Damit man mit dem Programmieren des Calliope im Jupyter Notebook beginnen kann,
#
# muss man zuerst den folgenden Code Block einfach ausführen.

# %%
##
#
# Bitte führe mich als erstes aus.
# Hierzu bitte einfach: "Shift + Enter" drücken.
#
##
from MakeCodeSim import *

basic = BasicSim()

# %% [markdown]
# **Aufgabe 1:**
#
# Bitte führe die untenstehende Funktion einmal aus.

# %%
##
#
# einfach ausführen
#
##

test_func()

# %% [markdown]
# ### Zweite Besonderheit

# %% [markdown]
# Damit der Calliope etwas machen kann, benötigt er eine spezielle Funktion.
#
# Diese Funktion soll per Verabredung **on_forever** heißen.

# %% [markdown]
# **Aufgabe 2:**
#
# Diese Funktion soll einfach mal "Hallo" auf der Konsole ausgeben.
#
# Der Name der Funktion soll **on_forever** sein.

# %%
##
#
# Bitte hier Code einfügen bzw. die Funktion entsprechend abändern.
#
##

def name_der_funktion():
    pass

# %% [markdown]
# ### Dritte Besonderheit

# %% [markdown]
# Der Calliope als Computer bzw. Recheneinheit in einem Roboter ist permanent an, sobald er Strom hat.
#
# Das heißt eine Funktion muss irgendwie gestartet werden, dass macht eine weitere Funktion diese heißt **basic.forever()**.
#
# Nennen wir sie einfach **Basis-Funktion**.

# %% [markdown]
# **Bitte genau lesen:**
#
# Dieser **Basis-Funktion**: **basic.forever()**,
#
# gibst du in ihren Klammern den Namen der Funktion (d.h. deiner geschriebenen),
#
# welche du starten willst mit d.h. in unserem Fall **on_forever**.
#
# Achtung bitte: **on_forever** ohne Klammern übergeben, als Parameter.

# %% [markdown]
# **Aufgabe 3:**
#
# Bitte übergib den Namen der Funktion (genauer gesagt die Referenz der Funktion) an die **Basis-Funktion**.

# %%
##
#
# Bitte hier Code einfügen bzw. die Funktion entsprechend abändern.
#
##

basic.forever_test(name_der_funktion)

# %% [markdown]
# Um das Pressen eines Buttons auf dem Calliope zu simulieren nutzen wir hier die Funktion **input_sim.button_is_pressed()**.
#
# Ein Calliope hat 2 Buttons, A und B.
#
# Um einen Button zu drücken wird nach dem Start des Programms durch **button_is_pressed()** eine Eingabe gefordert bei der man dann "a" für Button A oder "b" für Button B eingeben kann.
#
# Die **Basis-Funktion: basic.show_string()** wird genutzt um beim drücken eines Buttons eine Textausgabe im Terminal auszugeben.

# %% [markdown]
# **Aufgabe 4:**
#
# Der Button B beendet hier bereits das Programm.
#
# Beim pressen eines Buttons soll nun zusätzlich ein Name (z.B. "Max") im Terminal ausgegeben werden.
#
# Bitte verändere die Funktion so, dass beim ausführen des Programms, beim Pressen des Buttons A der Name ausgegeben wird.

# %%
##
#
# Aufgabe 4
#
##

def on_forever():
    ##
    # Code
    ##
    if input_sim.button_is_pressed(Button.A):
        pass
    

basic.forever_test(on_forever)

# %% [markdown]
# **Aufgabe 5:**
#
# Beim drücken eines Buttons soll das Programm jetzt einen Zähler hochzählen. (Wie **z.B. bei einem Rennen ein Rundenzähler.**)
#
# Bitte schreib ein Programm, dass beim drücken des Buttons hochzählt und jedes mal den gezählten Wert ausgiebt.

# %%
##
#
# Aufgabe 5
#
##

def on_forever():
    ##
    # Code
    ##
    if input_sim.button_is_pressed(Button.A):
        pass

basic.forever_test(on_forever)

# %% [markdown]
# **Aufgabe 6:**
#
# Manchmal ist es hilfreich wenn ein Programm erst etwas macht, wenn oft genug gedrückt wurde.
#
# Bitte schreibe ein Programm, dass erst nach ein paar mal drücken (**z.B. 4 mal**) etwas anzeigt.

# %%
##
#
# Aufgabe 6
#
##

def on_forever():
    ##
    # Code
    ##
    if input_sim.button_is_pressed(Button.A):
        pass

basic.forever_test(on_forever)

# %% [markdown]
# **Aufgabe 7:**
#
# Ein Button ist oft nicht genug um sinnvolle Eingaben an ein Programm weiter zu geben.
#
# Bitte schreib ein Programm, bei dem zwei Tasten genutzt werden können, bei einer Taste soll **“Start”** angezeigt werden, beim Drücken der anderen Taste soll **“Stop”** angezeigt werden.

# %%
##
#
# Aufgabe 7
#
##

def on_forever():
    ##
    # Code
    ##
    if input_sim.button_is_pressed(Button.A):
        pass

basic.forever_test(on_forever)
